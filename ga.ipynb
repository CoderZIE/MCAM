# %%
from moo import *
import csv
import itertools

# %%
from sko.GA import GA
import csv


# Define the fitness function for optimization
def fitness_function(params):
    # Rounding parameters since they must be integers (1, 2, 3)
    params = [round(x) for x in params]
    _, _, _, power = multi_objective_function(params)
    return power  # Minimize power

# Set up the Genetic Algorithm
ga = GA(
    func=fitness_function,        # Fitness function
    n_dim=3,                      # Number of parameters (3 elements in the array)
    size_pop=20,                  # Population size
    max_iter=50,                  # Number of iterations (generations)
    prob_mut=0.2,                 # Mutation probability
    lb=[0, 0, 0],                 # Lower bounds for each parameter
    ub=[2, 2, 2],                 # Upper bounds for each parameter
    precision=1                   # Precision to restrict to integers
)

# Run the Genetic Algorithm
best_params, best_power = ga.run()

# Get the best parameters as integers
best_params = [round(x) for x in best_params]

# Evaluate the best configuration
error, latency, area, power = multi_objective_function(best_params)

# Save results to CSV
csv_filename = "sko_ga_config_results.csv"
header = ["Param1", "Param2", "Param3", "Error", "Latency", "Area", "Power"]

with open(csv_filename, "w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(header)
    writer.writerow([*best_params, error, latency, area, power])

# Print the best configuration
print("Best configuration:")
print(f"Params: {best_params}, Error: {error}, Latency: {latency}, Area: {area}, Power: {power}")

# Plot the convergence of the algorithm
import matplotlib.pyplot as plt

plt.plot(ga.all_history_Y)
plt.xlabel("Iteration")
plt.ylabel("Power")
plt.title("Convergence of Genetic Algorithm")
plt.show()
# Out:
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.016 15.113999999999999 2.021
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.008 14.169 1.7650000000000001
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.018000000000000002 15.122 1.741
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.018000000000000002 15.122 1.741
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.0 13.224 1.509
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.016 15.113999999999999 2.021
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.008 14.169 1.7650000000000001
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.008 14.169 1.7650000000000001
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.008 14.169 1.7650000000000001
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.016 15.113999999999999 2.021
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.016 15.114 2.021
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.02 15.129999999999999 1.4609999999999999
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.018000000000000002 15.122 1.741
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.018000000000000002 15.122 1.741
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.008 14.169 1.7650000000000001
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.008 14.169 1.7650000000000001
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.0 13.224 1.509
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.018000000000000002 15.122 1.741
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.008 14.169 1.7650000000000001
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.016 15.113999999999999 2.021
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.0 13.224 1.509
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.008 14.169 1.7650000000000001
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.02 15.129999999999999 1.4609999999999999
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.02 15.129999999999999 1.4609999999999999
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.008 14.169 1.7650000000000001
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.0 13.224 1.509
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.018000000000000002 15.122 1.741
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.0 13.224 1.509
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.02 15.129999999999999 1.4609999999999999
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.016 15.113999999999999 2.021
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.008 14.169 1.7650000000000001
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.0 13.224 1.509
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.008 14.169 1.7650000000000001
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.0 13.224 1.509
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.0 13.224 1.509
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.0 13.224 1.509
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.0 13.224 1.509
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.008 14.169 1.7650000000000001
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.0 13.224 1.509
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.018000000000000002 15.122 1.741
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.008 14.169 1.7650000000000001
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.018000000000000002 15.122 1.741
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.018000000000000002 15.122 1.741
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.018000000000000002 15.122 1.741
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.0 13.224 1.509
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.02 15.129999999999999 1.4609999999999999
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.0 13.224 1.509
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.02 15.129999999999999 1.4609999999999999
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.0 13.224 1.509
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.008 14.169 1.7650000000000001
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.0 13.224 1.509
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.008 14.169 1.7650000000000001
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 16.067 0.026000000000000002 1.9969999999999999
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.02 15.129999999999999 1.4609999999999999
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.02 15.129999999999999 1.4609999999999999
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.008 14.169 1.7650000000000001
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.02 15.129999999999999 1.4609999999999999
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.02 15.129999999999999 1.4609999999999999
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.008 14.169 1.7650000000000001
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.02 15.129999999999999 1.4609999999999999
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.02 15.129999999999999 1.4609999999999999
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.0 13.224 1.509
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.018000000000000002 15.122 1.741
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.02 15.129999999999999 1.4609999999999999
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.018000000000000002 15.122 1.741
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.0 13.224 1.509
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.018000000000000002 15.122 1.741
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.018000000000000002 15.122 1.741
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 0.018000000000000002 15.122 1.741
# MRED_sampled:  0.1464413167840984
# 0.1464413167840984 1.4849999999999999 14.177 0.01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 25
#      13 ga = GA(
#      14     func=fitness_function,        # Fitness function
#      15     n_dim=3,                      # Number of parameters (3 elements in the array)
#    (...)
#      21     precision=1                   # Precision to restrict to integers
#      22 )
#      24 # Run the Genetic Algorithm
# ---> 25 best_params, best_power = ga.run()
#      27 # Get the best parameters as integers
#      28 best_params = [round(x) for x in best_params]
#
# File /workspace/myenv/lib/python3.10/site-packages/sko/GA.py:82, in GeneticAlgorithmBase.run(self, max_iter)
#      80 for i in range(self.max_iter):
#      81     self.X = self.chrom2x(self.Chrom)
# ---> 82     self.Y = self.x2y()
#      83     self.ranking()
#      84     self.selection()
#
# File /workspace/myenv/lib/python3.10/site-packages/sko/GA.py:51, in GeneticAlgorithmBase.x2y(self)
#      50 def x2y(self):
# ---> 51     self.Y_raw = self.func(self.X)
#      52     if not self.has_constraint:
#      53         self.Y = self.Y_raw
#
# File /workspace/myenv/lib/python3.10/site-packages/sko/tools.py:113, in func_transformer.<locals>.func_transformed(X)
#     112 def func_transformed(X):
# --> 113     return np.array([func(x) for x in X])
#
# File /workspace/myenv/lib/python3.10/site-packages/sko/tools.py:113, in <listcomp>(.0)
#     112 def func_transformed(X):
# --> 113     return np.array([func(x) for x in X])
#
# Cell In[5], line 9, in fitness_function(params)
#       6 def fitness_function(params):
#       7     # Rounding parameters since they must be integers (1, 2, 3)
#       8     params = [round(x) for x in params]
# ----> 9     _, _, _, power = multi_objective_function(params)
#      10     return power
#
# File /workspace/Trial-1/moo.py:11, in multi_objective_function(x)
#       5 """
#       6 This function calculates four objectives: MRED, Latency, Area, and Power.
#       7 The calculation is arbitrary for demonstration purposes. Replace these with your actual equations.
#       8 """
#      10 # Replace these with actual formulas for MRED, Latency, Area, and Power
# ---> 11 error = MRED(x)  # Example: Sum of squares
#      13 # Calculate Latency, Area, and Power using the optimizationPram function
#      14 Latency, Power, Area = optimizationParam(x)
#
# File /workspace/Trial-1/mred.py:23, in MRED(x)
#      20 count = 0
#      22 for a, b in samples:
# ---> 23     approx_result = multiply2(a, b)
#      24     exact_result = a * b
#      26     if exact_result != 0:  # Avoid division by zero
#
# File /workspace/Trial-1/temp.py:116, in multiply2(A, B)
#     114     k = []
#     115     for j in range(N):
# --> 116         k.append(AND(A[j],B[M-1-i]))
#     117     L.append(k)
#     119 ##column 5
#
# File /workspace/Trial-1/temp.py:4, in AND(A, B)
#       2 def AND(A,B):
#       3     A=int(A)
# ----> 4     B=int(B)
#       5     return A&B
#
# KeyboardInterrupt:
